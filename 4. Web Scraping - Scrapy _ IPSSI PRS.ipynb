# %% [markdown]
# # 4. Web Scraping - Scrapy
#
# <img src='https://xn--kvin-duranty-beb.fr/wp-content/uploads/2022/10/Web-Scraping-_-IPSSI-PRS-3.png'>
#
# Dans cet exercice, nous utiliserons la bibliothèque scrapy afin de collecter les données des sites internet suivants :
#
# - Partie 1 : [AlloCiné](https://www.allocine.fr/film/meilleurs)
# Nous collecterons les informations des meilleurs films recensés par la platforme.
#
#
# - Partie 2 : [Boursorama](https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC)
# Nous collecterons les données boursières des entreprises du CAC40.

# %% [markdown]
# # Parie 1 - Les meilleurs films selon [Allociné.fr](https://www.allocine.fr/film/meilleurs/)
#
# <img src= 'https://fr.web.img2.acsta.net/newsv7/15/10/19/21/14/237930.jpg'>
#
# L'objectif de cet exercice est de collecter les données des meilleurs films présents sur la page `https://www.allocine.fr/film/meilleurs/` du site allocine.fr.
#
# Les données que nous collecterons seront les suivantes :
# - Les titres du film
# - Les liens des images
# - Les noms des auteurs
# - Les durées des films
# - Les genres cinématographiques
# - Les scores des films
# - Les descriptions des films
# - Les dates de sortie des films
#
# ## 4.1 Installez scrapy à l'aide de la commande suivante :
#
#
# `pip install scrapy`
#
#
# ## 4.2 Générez un environement de travail scrapy en executant la commande suivante :

# %%
# Création du dossier WebCrawler contenant l'ensemble des fichiers utiles au fonctionnement de scrapy
# !scrapy startproject WebCrawler
# Out:
# New Scrapy project 'WebCrawler', using template directory 'C:\Users\LeoDOYEN\anaconda3\lib\site-packages\scrapy\templates\project', created in:
#     C:\Users\LeoDOYEN\weebScrapping\WebCrawler
#
# You can start your first spider with:
#     cd WebCrawler
#     scrapy genspider example example.com

# %%
# Création du projet AlloCiné dans le dossier WebCrawler/spider
# !cd WebCrawler && scrapy genspider allocine https://www.allocine.fr/film/meilleurs
# Out:
# Created spider 'allocine' using template 'basic' in module:
#   WebCrawler.spiders.allocine

# %% [markdown]
# Les fichiers de scrapy que nous manipulerons seront :
#
# 1. le fichier `items.py` qui contient les champs que nous souhaitons collecter (ex : nom des films, score, date de publication). Chaque champs sera introduit dans la class `ReviewsAllocineItem` avec la nomenclature suivante : `name = scrapy.Field()`.
#
#
# 2. le fichier `allocine.py` qui contient les fonctions qui permetons la collecte.

# %% [markdown]
# ## 4.3 Ajoutez dans le fichier `items.py` les champs que nous souhaitons collecter.
#
# Ajoutez dans la class `ReviewsAllocineItem(scrapy.Item)` les champs suivants,
# pour rappel la nomenclature des champs est la suivante :
#
# `name = scrapy.Field()`.
#
# - title
# - img
# - author
# - time
# - genre
# - score
# - desc
# - release

# %%
#À ajouter au fichier items.py
class ReviewsAllocineItem(scrapy.Item):
     pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 #À ajouter au fichier items.py
# ----> 2 class ReviewsAllocineItem(scrapy.Item):
#       3      pass
#
# NameError: name 'scrapy' is not defined

# %% [markdown]
# ## 4.3 Lancez votre terminal puis exécutez la commande suivante :
#
# C'est dans le terminale que nous intéragirons avec scrapy pour manipuler les bases du site allocine.fr

# %% [markdown]
# `scrapy shell`
#
# `url = 'https://www.allocine.fr/film/meilleurs'`
#
# `fetch(url)`

# %% [markdown]
# ## 4.4 Exécutez dans votre terminal les commandes suivantes et notez vos observations.
#
# Repérez en parallèle à quelles balises correspondent vos résultats.
#
# `response`
#
# <200 https://www.allocine.fr/film/meilleurs/>
#
# `response.css('a')`
#
#
#
# `len(response.css('a'))`
#
#     126
#
# `response.css('a::text')`
#
#
#
# `response.css('a')[0].attrib`
#
#     'href': '/tag-1026/films/'
#
# `response.css('a')[0].attrib['href']`
#
#     /tag-1026/films/
#
# `response.css('a::text')[0].extract()`
#
#     Meilleurs teen movies
#
# `response.css('h1.item')`
#
#     <Selector xpath="descendant-or-self::h1[@class and contains(concat(' ', normalize-space(@class), ' '), ' item ')]" data='<h1 class="item">\nTop films </h1></di...'>]
#
# `response.css('h1.item::text')`
#
#     <Selector xpath="descendant-or-self::h1[@class and contains(concat(' ', normalize-space(@class), ' '), ' item ')]/text()" data='\nTop films '>
#
# `response.css('h1.item::text')[0].extract()`
#
#        \nTop films
#
# `response.css('img')`
#
#       <Selector xpath='descendant-or-self::img' data='<img class="header-main-logo-img" src...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="avatar js-myaccount-avata...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="avatar js-myaccount-avata...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="https...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="https...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="data:...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="data:...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="data:...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="data:...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="data:...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="data:...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="data:...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="data:...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="data:...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="data:...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="data:...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="data:...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="data:...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="data:...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="data:...'>,
#      <Selector xpath='descendant-or-self::img' data='<img class="thumbnail-img" src="data:...'>

# %% [markdown]
# ## 4.5 Recherchez les informations suivantes sous forme de chaine de caractère (str) :
#
# 0. La balise qui liste l'ensemble des films
# 1. Le titre du premier film
# 2. Le lien de l'image du premier film
# 3. Le nom de l'auteur du premier film
# 4. La durée du premier film
# 5. Le genre cinématographique du premier film
# 6. Le score du premier film
# 7. La description du premier film
# 8. La date de sortie du premier film

# %%
# 0. La balise qui liste l'ensemble des films


#1. Le titre du premier film


#2. Le lien de l'image du premier film


#3. Le nom de l'auteur du premier film


#4. La durée du premier film 


#5. Le genre cinématographique du premier film


#6. Le score du premier film


#7. La description du premier film


#8. La date de sortie du premier film

# %% [markdown]
# ## 4.6 Complétez le code suivante en fonction des résultats obtenus à la question précédentes

# %%
import scrapy
from scrapy import Request
from WebCrawler.items import ReviewsAllocineItem


class AllocineSpider(scrapy.Spider):
    name = 'allocine'
    allowed_domains = ['www.allocine.fr']
    
    #Liste des pages à collecter
    start_urls = [f'https://www.allocine.fr/film/meilleurs/?page={n}' for n in range(1,10)]


    def start_requests(self):
        for url in self.start_urls:
            yield Request(url=url, callback=self.parse_manga)
        
        
    def parse_manga(self, response):
        liste_film = #à compléter
        
        
        # Boucle qui parcours l'ensemble des éléments de la liste des films
        for film in liste_film:
            item = ReviewsAllocineItem()

            # Nom du film
            try:
                item['title'] = #à compléter
            except:
                item['title'] = 'None'
              
            # Lien de l'image du film
            try:
                item['img'] = #à compléter
            except:
                item['img'] = 'None'


            # Auteur du film
            try:
                item['author'] = #à compléter
            except:
                item['author'] = 'None'
           
            # Durée du film
            try:
                item['time'] = #à compléter
            except:
                item['time'] = 'None'

            # Genre cinématographique
            try:
                item['genre'] = #à compléter
            except:
                 item['genre'] = 'None'

            # Score du film
            try:
                item['score'] = #à compléter
            except:
                item['score'] = 'None'

            # Description du film
            try:
                item['desc'] = #à compléter
            except:
                item['desc'] = 'None'

            # Date de sortie
            try:
                item['release'] = #à compléter
            except:
                item['release'] = 'None'


            yield item
# Out:
#   Input In [4]
#     liste_film = #à compléter
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 4.7 Ajoutez l'ensemble de votre code au fichier `allocine.py` se trouvant dans le dossier `spider`, exécutant la commande suivante afin d'obtenir le fichier `allocine.csv` contenant les données collectées.

# %%
# !cd WebCrawler/WebCrawler/spiders && scrapy crawl allocine -o allocine.csv
# Out:
# Traceback (most recent call last):
#   File "C:\Users\LeoDOYEN\anaconda3\Scripts\scrapy-script.py", line 10, in <module>
#     sys.exit(execute())
#   File "C:\Users\LeoDOYEN\anaconda3\lib\site-packages\scrapy\cmdline.py", line 144, in execute
#     cmd.crawler_process = CrawlerProcess(settings)
#   File "C:\Users\LeoDOYEN\anaconda3\lib\site-packages\scrapy\crawler.py", line 290, in __init__
#     super().__init__(settings)
#   File "C:\Users\LeoDOYEN\anaconda3\lib\site-packages\scrapy\crawler.py", line 167, in __init__
#     self.spider_loader = self._get_spider_loader(settings)
#   File "C:\Users\LeoDOYEN\anaconda3\lib\site-packages\scrapy\crawler.py", line 161, in _get_spider_loader
#     return loader_cls.from_settings(settings.frozencopy())
#   File "C:\Users\LeoDOYEN\anaconda3\lib\site-packages\scrapy\spiderloader.py", line 67, in from_settings
#     return cls(settings)
#   File "C:\Users\LeoDOYEN\anaconda3\lib\site-packages\scrapy\spiderloader.py", line 24, in __init__
#     self._load_all_spiders()
#   File "C:\Users\LeoDOYEN\anaconda3\lib\site-packages\scrapy\spiderloader.py", line 51, in _load_all_spiders
#     for module in walk_modules(name):
#   File "C:\Users\LeoDOYEN\anaconda3\lib\site-packages\scrapy\utils\misc.py", line 88, in walk_modules
#     submod = import_module(fullpath)
#   File "C:\Users\LeoDOYEN\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\LeoDOYEN\weebScrapping\WebCrawler\WebCrawler\spiders\allocine.py", line 5, in <module>
#     class AllocineSpider(scrapy.Spider):
# NameError: name 'scrapy' is not defined

# %% [markdown]
# ## 4.7 Importez la bibliothèque Pandas puis visualisez votre collecte de données

# %%
import pandas as pd

df = pd.read_csv("WebCrawler/WebCrawler/spiders/allocine.csv") 
df
# Out:
#                   author                                               desc  \
# 0      Quentin Tarantino  L'odyssée sanglante et burlesque de petits mal...
# 1        Robert Zemeckis  Quelques décennies d'histoire américaine, des ...
# 2           Sergio Leone  Un mystérieux desperado pourchasse sans relâch...
# 3                   None  Pendant la Guerre de Sécession, Tuco, Joe et S...
# 4                   None  Il était une fois deux truands juifs, Max et N...
# 5                   None  Le parcours d'un chasseur de prime allemand et...
# 6       Steven Spielberg  Evocation des années de guerre d'Oskar Schindl...
# 7          Peter Jackson  Frodon le Hobbit hérite de l'Anneau Unique, un...
# 8           Ridley Scott  Le général romain Maximus est le plus fidèle s...
# 9                   None  Walt Kowalski est un ancien de la guerre de Co...
# 10                  None  Frodon Sacquet, le Hobbit, doit braver de terr...
# 11        Frank Darabont  Paul Edgecomb, Gardien-chef du pénitencier de ...
# 12          Sidney Lumet  Lors d'un procès, un juré émet l'hypothèse que...
# 13  Francis Ford Coppola  En 1945, à New York, les Corleone sont une des...
# 14     Christopher Nolan  Le film raconte les aventures d’un groupe d’ex...
# 15                  None  Condamné à perpétuité pour le meurtre de sa fe...
# 16         Peter Jackson  Tandis que les ténèbres se répandent sur la Te...
# 17          Roger Allers  Le long combat de Simba le lionceau pour accéd...
# 18          Milos Forman  Rebellion dans un hôpital psychiatrique à l'in...
# 19     Christopher Nolan  Batman entreprend de démanteler les dernières ...
#
#                          genre  \
# 0            Policier,Thriller
# 1        Comédie,Drame,Romance
# 2                      Western
# 3                      Western
# 4               Policier,Drame
# 5                      Western
# 6            Historique,Guerre
# 7         Aventure,Fantastique
# 8              Action,Aventure
# 9               Drame,Thriller
# 10        Aventure,Fantastique
# 11        Policier,Fantastique
# 12                       Drame
# 13              Policier,Drame
# 14       Drame,Science Fiction
# 15                       Drame
# 16        Aventure,Fantastique
# 17  Aventure,Animation,Musical
# 18                       Drame
# 19             Action,Thriller
#
#                                                   img            release  \
# 0   https://fr.web.img2.acsta.net/c_310_420/medias...               None
# 1   https://fr.web.img2.acsta.net/c_310_420/pictur...    28 octobre 2015
# 2   https://fr.web.img3.acsta.net/c_310_420/pictur...    10 octobre 2018
# 3   ......    5 novembre 2014
# 4   ......         6 mai 2015
# 5   ......               None
# 6   https://fr.web.img4.acsta.net/c_310_420/pictur...       13 mars 2019
# 7   ......               None
# 8   ......               None
# 9   ......               None
# 10  ......               None
# 11  ......               None
# 12  ......    25 juillet 2007
# 13  ......    23 février 2022
# 14  ......               None
# 15  ......               None
# 16  ......               None
# 17  ......      11 avril 2012
# 18  ......  16 septembre 2009
# 19  ......               None
#
#       score      time                                              title
# 0   4,4,4,5  2h 29min                                       Pulp Fiction
# 1   2,6,4,6  2h 20min                                       Forrest Gump
# 2   4,0,4,5  2h 55min                     Il était une fois dans l'Ouest
# 3   4,1,4,5  3h 00min                      Le Bon, la brute et le truand
# 4   4,9,4,5  3h 40min                      Il était une fois en Amérique
# 5   4,6,4,5  2h 44min                                   Django Unchained
# 6   4,2,4,6  3h 15min                              La Liste de Schindler
# 7   3,7,4,5  2h 58min  Le Seigneur des anneaux : la communauté de l'a...
# 8   4,3,4,5  2h 35min                                          Gladiator
# 9   4,7,4,5  1h 56min                                        Gran Torino
# 10  4,0,4,5  2h 59min           Le Seigneur des anneaux : les deux tours
# 11  2,8,4,6  3h 09min                                     La Ligne verte
# 12  5,0,4,6  1h 35min                                12 hommes en colère
# 13  4,6,4,5  2h 55min                                         Le Parrain
# 14  3,8,4,5  2h 49min                                       Interstellar
# 15  3,2,4,5  2h 22min                                         Les Evadés
# 16  3,8,4,5  3h 21min         Le Seigneur des anneaux : le retour du roi
# 17  3,4,4,5  1h 29min                                        Le Roi Lion
# 18  5,0,4,5  2h 09min                   Vol au-dessus d'un nid de coucou
# 19  4,0,4,5  2h 32min                 The Dark Knight, Le Chevalier Noir

# %% [markdown]
# # Partie 2 - Cotations boursières du CAC40 - [Boursorama](https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC)
#
#
# <img src='data:image/png;base64,...'>
#
#
#
# L'objectif de cet exercice sera de collecter les données en temps réelle des actions du CAC40.
# Les données que nous collecterons serons :
#
# - le nom de l'indice boursier
# - le cours de l'action
# - la variation de l'action
# - la valeur la plus haute de la séance
# - la valeur la plus basse
# - la valeur d'ouverture
# - la date et l'heure de la collecte
#
#
# ## Lancez le projet scrapy
#
# Créez le projet scrapy nomé `boursorama` en utilisant le lien suivant `https://www.boursorama.com/bourse/actions/palmares/france/page-1`.
#
# Pour rappel la commande scrapy pour génére un nouveau spider est la suivante :
#
# `scrapy genspider nom_du_projet adresse_url`

# %%
import pandas as pd

df = pd.read_csv("WebCrawler/WebCrawler/spiders/boursorama.csv") 
df
# Out:
#          cours       hight               indice         low       open_  \
# 0       9.076       9.142    CREDIT AGRICOLE SA      9.044       9.111
# 1     132.560     134.220           AIR LIQUIDE    131.280     132.800
# 2     105.660     105.880                AIRBUS    104.300     104.360
# 3      20.060      20.070                ALSTOM     19.230      19.240
# 4      48.180      48.565                DANONE     47.685      48.455
# 5      47.240      47.650           BNP PARIBAS     47.030      47.445
# 6      15.345      15.595             CARREFOUR     15.175      15.535
# 7     172.850     175.400             CAPGEMINI    171.850     171.900
# 8      24.875      25.035                   AXA     24.755      24.910
# 9      91.800      92.270                 VINCI     91.080      91.620
# 10     34.345      35.795     DASSAULT SYSTEMES     34.235      35.340
# 11    164.400     166.950      ESSILORLUXOTTICA    164.000     164.850
# 12     28.510      28.540              BOUYGUES     28.020      28.190
# 13     13.032      13.130                 ENGIE     12.974      13.030
# 14     65.080      65.260   EUROFINS SCIENTIFIC     64.020      64.820
# 15     23.195      23.470      SOCIETE GENERALE     23.190      23.375
# 16    125.600     126.000                THALES    122.150     122.250
# 17    473.150     476.250                KERING    470.250     472.750
# 18     78.120      78.360               LEGRAND     76.100      76.260
# 19    652.400     663.600                  LVMH    651.100     659.400
# 20     24.830      24.845              MICHELIN     23.700      23.700
# 21    318.350     322.900               L'OREAL    318.100     321.400
# 22      9.488       9.514                ORANGE      9.378       9.420
# 23     57.180      58.560       PUBLICIS GROUPE     57.060      58.560
# 24    174.600     177.050         PERNOD RICARD    173.050     176.900
# 25  1 347.500   1 374.000           HERMES INTL  1 342.000   1 355.500
# 26     31.845      32.200               RENAULT     31.500      31.700
# 27    112.340     112.740                SAFRAN    110.100     110.200
# 28     83.240      83.350                SANOFI     82.330      82.700
# 29     41.640      42.105          SAINT-GOBAIN     41.405      41.425
# 30     13.554      13.608            STELLANTIS     13.400      13.496
# 31     34.165      34.670    STMICROELECTRONICS     33.920      34.195
# 32    132.480     133.660    SCHNEIDER ELECTRIC    131.300     131.380
# 33    273.100     275.600       TELEPERFORMANCE    271.100     274.000
# 34     52.920      53.370         TOTALENERGIES     52.410      53.000
# 35     22.460      23.070                VEOLIA     22.450      22.730
# 36      8.224       8.296               VIVENDI      8.164       8.296
# 37     44.360      44.740             WORLDLINE     43.300      43.670
#
#                           time     var
# 0   2022-10-26 15:41:28.899421  -0.20%
# 1   2022-10-26 15:41:28.902423  +0.05%
# 2   2022-10-26 15:41:28.904422  +1.54%
# 3   2022-10-26 15:41:28.905423  +4.21%
# 4   2022-10-26 15:41:28.907422  -0.83%
# 5   2022-10-26 15:41:28.909424  -0.20%
# 6   2022-10-26 15:41:28.910422  -1.25%
# 7   2022-10-26 15:41:28.912422  -0.09%
# 8   2022-10-26 15:41:28.913421  -0.38%
# 9   2022-10-26 15:41:28.920423  +1.79%
# 10  2022-10-26 15:41:28.922424  -6.35%
# 11  2022-10-26 15:41:28.924423  -0.36%
# 12  2022-10-26 15:41:28.925423  +1.35%
# 13  2022-10-26 15:41:28.927423  -0.08%
# 14  2022-10-26 15:41:28.929425  +0.15%
# 15  2022-10-26 15:41:28.936428  -0.32%
# 16  2022-10-26 15:41:28.938424  +3.29%
# 17  2022-10-26 15:41:28.939424  +0.16%
# 18  2022-10-26 15:41:28.940424  +2.20%
# 19  2022-10-26 15:41:28.942428  -0.85%
# 20  2022-10-26 15:41:28.944425  -2.74%
# 21  2022-10-26 15:41:28.954425  -1.03%
# 22  2022-10-26 15:41:28.955425  +0.88%
# 23  2022-10-26 15:41:28.957429  -2.36%
# 24  2022-10-26 15:41:28.959425  -1.66%
# 25  2022-10-26 15:41:29.001430  -0.52%
# 26  2022-10-26 15:41:29.008431  +0.02%
# 27  2022-10-26 15:41:29.020431  +1.81%
# 28  2022-10-26 15:41:29.022431  +1.15%
# 29  2022-10-26 15:41:29.024430  +0.36%
# 30  2022-10-26 15:41:29.025432  +0.16%
# 31  2022-10-26 15:41:29.032433  -2.89%
# 32  2022-10-26 15:41:29.033433  +0.90%
# 33  2022-10-26 15:41:29.036432  -0.62%
# 34  2022-10-26 15:41:29.039434  -0.62%
# 35  2022-10-26 15:41:29.045434  -1.19%
# 36  2022-10-26 15:41:29.051434  -1.15%
# 37  2022-10-26 15:41:29.053433  +1.35%

# %% [markdown]
# ## Modifiez le fichier items.py en ajoutant les champs à collecter
#
# Ajoutez une class `ReviewsBoursoramaItem(scrapy.Item)` puis les champs avec la nomenclature `name = scrapy.Field()`

# %% [markdown]
# ## Lancez le shell scrapy

# %% [markdown]
# `scrapy shell`
#
# `url = 'https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC'`
#
# `fetch(url)`

# %% [markdown]
# ## Compléter le code suivant puis ajoutez-le au fichier `boursorama.py`.

# %%
import scrapy
from scrapy import Request
from WebCrawler.items import #Importe la class contenant vos items (champs collectés) ==> à compléter
import time

class BoursoramaSpider(scrapy.Spider):
    name = 'boursorama'
    allowed_domains = ['finance.yahoo.com']
    start_urls = #[Liste des URL à compléter]

    def start_requests(self):
        for url in self.start_urls:
            yield Request(url=url, callback=self.parse_boursorama)
            
    def parse_boursorama(self, response):
        liste_indices = response.css('tr.c-table__row')[1:]
        
        for indices in liste_indices:
            item = #importer la class Items du projet provenant du fichier items.py
            
            #indice boursier
            try: 
              item['indice'] = #à compléter
            except:
              item['indice'] = 'None'
            
            #indice cours de l'action
            try: 
              item['cours'] = #à compléter
            except:item['cours'] = 'None'
            
            #Variation de l'action
            try: 
              item['var'] = #à compléter
            except:
              item['var'] = 'None'
            
            #Valeur la plus haute
            try: 
              item['hight'] = #à compléter
            except:
              item['hight'] = 'None'
            
            #Valeur la plus basse
            try: 
              item['low'] = #à compléter
            except:
              item['low'] = 'None'

            #Valeur d'ouverture
            try: 
              item['open_'] = #à compléter
            except:
              item['open_'] = 'None'

            #Date de la collecte
            try: 
              item['time'] = #à compléter
            except:
              item['time'] = 'None'

            
            yield item

# %% [markdown]
# ## Executez la commande suivante afin de collecter vos données

# %%
# !cd WebCrawler/WebCrawler/spiders && scrapy crawl (nom_du_projet::à compléter) -o (nom_du_fichier_csv::à compléter)

# %% [markdown]
# # Bonus - [MyAnimeListe](https://myanimelist.net/manga.php?letter=A)
#
# <img src='https://image.myanimelist.net/ui/OK6W_koKDTOqqqLDbIoPArR89MP-ulHxaLCJ2P-BfXg'>
#
# Reproduisez l'ensemble de la procédure en collectant les données du site [MyAnimeListe](https://myanimelist.net/manga.php?letter=A).
#
# Les données à collecter :
# - le nom des animés
# - l'image des animés
# - la description des animés.
#
# Utilisez la class `DataBase` pour stoquer vos donneés dans une base de données.

# %%
import sqlalchemy as db

class DataBase():
    def __init__(self, name_database='database'):
        self.name = name_database
        self.url = f"sqlite:///{name_database}.db"
        self.engine = db.create_engine(self.url)
        self.connection = self.engine.connect()
        self.metadata = db.MetaData()
        self.table = self.engine.table_names()
       
    
    def create_table(self, name_table, **kwargs):
        colums = [db.Column(k, v, primary_key = True) if 'id_' in k else db.Column(k, v) for k,v in kwargs.items()]
        db.Table(name_table, self.metadata, *colums)
        self.metadata.create_all(self.engine)
        print(f"Table : '{name_table}' are created succesfully")
        
    def read_table(self, name_table, return_keys=False):
        table = db.Table(name_table, self.metadata, autoload=True, autoload_with=self.engine)
        if return_keys:table.columns.keys() 
        else : return table
        
        
    def add_row(self, name_table, **kwarrgs):
        name_table = self.read_table(name_table)
        
        stmt = (
            db.insert(name_table).
            values(kwarrgs)
        )
        self.connection.execute(stmt)
        print(f'Row id added')
        
        
    def delete_row_by_id(self, table, id_):
        name_table = self.read_table(name_table) 
        
        stmt = (
            db.delete(name_table).
            where(students.c.id_ == id_)
            )
        self.connection.execute(stmt)
        print(f'Row id {id_} deleted')
        
    def select_table(self, name_table):
        name_table = self.read_table(name_table)       
        stm = db.select([name_table])
        return self.connection.execute(stm).fetchall()

# %%
#Générer un projet scrapy
# !cd WebCrawler && scrapy genspider manga https://myanimelist.net/manga.php?letter=A
    
# Collecter les données
# !cd WebCrawler/WebCrawler/spiders && scrapy crawl (nom_du_projet::à compléter) -o (nom_du_fichier_CSV::à compléter)
